# %%
import tensorflow as tf
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Model
import os
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import Model
import tensorflow_datasets as tfds
import glob
import imageio
import PIL
from IPython import display
import time
import random

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weapondetection/Weapons',
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(256, 256), 
    batch_size=32,
    shuffle=True
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weapondetection/Weapons',
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(256, 256), 
    batch_size=32,
    shuffle=True
)
# Out:
# Found 8093 files belonging to 2 classes.
# Using 6475 files for training.
# Found 8093 files belonging to 2 classes.
# Using 1618 files for validation.

# %%
class_names = ['Norm', 'Weapon']

fig = plt.figure(figsize=(9, 12))
for image, label in train_ds.take(1):
  for i in range(3):
    print()
    plt.subplot(1, 3, i + 1)
    plt.imshow((image[i]).numpy().astype('int32'))
    plt.title(class_names[label[i].numpy()])
    plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y))

# %%
optimizer = tf.keras.optimizers.Adam()

entropy = tf.keras.losses.BinaryCrossentropy()

metric = tf.keras.metrics.BinaryAccuracy()

# %%
def DiffAugment(x, policy='', channels_first=False):
    if policy:
        if channels_first:
            x = tf.transpose(x, [0, 2, 3, 1])
        for p in policy.split(','):
            for f in AUGMENT_FNS[p]:
                x = f(x)
        if channels_first:
            x = tf.transpose(x, [0, 3, 1, 2])
    return x


def rand_brightness(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) - 0.5
    x = x + magnitude
    return x


def rand_saturation(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) * 2
    x_mean = tf.reduce_mean(x, axis=3, keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_contrast(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) + 0.5
    x_mean = tf.reduce_mean(x, axis=[1, 2, 3], keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_translation(x, ratio=0.125):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    shift = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    translation_x = tf.random.uniform([batch_size, 1], -shift[0], shift[0] + 1, dtype=tf.int32)
    translation_y = tf.random.uniform([batch_size, 1], -shift[1], shift[1] + 1, dtype=tf.int32)
    grid_x = tf.clip_by_value(tf.expand_dims(tf.range(image_size[0], dtype=tf.int32), 0) + translation_x + 1, 0, image_size[0] + 1)
    grid_y = tf.clip_by_value(tf.expand_dims(tf.range(image_size[1], dtype=tf.int32), 0) + translation_y + 1, 0, image_size[1] + 1)
    x = tf.gather_nd(tf.pad(x, [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_x, -1), batch_dims=1)
    x = tf.transpose(tf.gather_nd(tf.pad(tf.transpose(x, [0, 2, 1, 3]), [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_y, -1), batch_dims=1), [0, 2, 1, 3])
    return x


def rand_cutout(x, ratio=0.5):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    cutout_size = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    offset_x = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[0] + (1 - cutout_size[0] % 2), dtype=tf.int32)
    offset_y = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[1] + (1 - cutout_size[1] % 2), dtype=tf.int32)
    grid_batch, grid_x, grid_y = tf.meshgrid(tf.range(batch_size, dtype=tf.int32), tf.range(cutout_size[0], dtype=tf.int32), tf.range(cutout_size[1], dtype=tf.int32), indexing='ij')
    cutout_grid = tf.stack([grid_batch, grid_x + offset_x - cutout_size[0] // 2, grid_y + offset_y - cutout_size[1] // 2], axis=-1)
    mask_shape = tf.stack([batch_size, image_size[0], image_size[1]])
    cutout_grid = tf.maximum(cutout_grid, 0)
    cutout_grid = tf.minimum(cutout_grid, tf.reshape(mask_shape - 1, [1, 1, 1, 3]))
    mask = tf.maximum(1 - tf.scatter_nd(cutout_grid, tf.ones([batch_size, cutout_size[0], cutout_size[1]], dtype=tf.float32), mask_shape), 0)
    x = x * tf.expand_dims(mask, axis=3)
    return x


AUGMENT_FNS = { 
    'color': [rand_brightness, rand_saturation, rand_contrast],
    'translation': [rand_translation],
    'cutout': [rand_cutout]
}

# %%
def basic_block(x, filter, stride):
  input = x

  x = layers.Conv2D(filter, 3, stride, padding='same', kernel_initializer="he_normal")(x)
  x = layers.BatchNormalization()(x)
  x = layers.ReLU()(x)

  x = layers.Conv2D(filter, 3, 1, padding='same', kernel_initializer="he_normal")(x)
  x = layers.BatchNormalization()(x)
  
  if stride != 1:
    input = layers.Conv2D(filter, 1, 2, padding='same', kernel_initializer="he_normal")(input)
    input = layers.BatchNormalization()(input)

  x = layers.Add()([x, input])
  x = layers.ReLU()(x)

  return x

# %%
def resnet18():

  input = layers.Input((256, 256, 3))
  x = layers.ZeroPadding2D((3, 3))(input)
  x = layers.Conv2D(64, 7, 2, padding='same', kernel_initializer="he_normal")(x)
  x = layers.BatchNormalization()(x)
  x = layers.ReLU()(x)
  x = layers.MaxPool2D(3, 2, padding='same')(x)

  num_blocks = [2, 2, 2, 2]
  filter = 64
  for i in range(len(num_blocks)):
    for j in range(num_blocks[i]):
      x = basic_block(x, filter, [2, 1][i == 0])
    filter *= 2

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Flatten()(x)
  x = layers.Dense(1, activation='sigmoid')(x)

  model = tf.keras.models.Model(inputs = input, outputs = x, name = "ResNet18")
  return model


classifier = resnet18()
classifier.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 131, 131, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 131, 131, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 131, 131, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 66, 66, 64)   0           ['re_lu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 66, 66, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 66, 66, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 66, 66, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 66, 66, 64)   36928       ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 66, 66, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 66, 66, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 66, 66, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 66, 66, 64)   36928       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 66, 66, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 66, 66, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 66, 66, 64)   36928       ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 66, 66, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 66, 66, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 66, 66, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 33, 33, 128)  73856       ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 33, 33, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 33, 33, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 33, 33, 128)  147584      ['re_lu_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 33, 33, 128)  8320        ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 33, 33, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 33, 33, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 33, 33, 128)  0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 33, 33, 128)  0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 17, 17, 128)  147584      ['re_lu_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 17, 17, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 17, 17, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 17, 17, 128)  147584      ['re_lu_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 17, 17, 128)  16512       ['re_lu_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 17, 17, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 17, 17, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 17, 17, 128)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 17, 17, 128)  0           ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 9, 9, 256)    295168      ['re_lu_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 9, 9, 256)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 9, 9, 256)    590080      ['re_lu_9[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 9, 9, 256)    33024       ['re_lu_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 9, 9, 256)    0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  re_lu_10 (ReLU)                (None, 9, 9, 256)    0           ['add_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 5, 5, 256)    590080      ['re_lu_10[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 5, 5, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 5, 5, 256)    0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 5, 5, 256)    590080      ['re_lu_11[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 5, 5, 256)    65792       ['re_lu_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 5, 5, 256)   1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 5, 5, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 5, 5, 256)    0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  re_lu_12 (ReLU)                (None, 5, 5, 256)    0           ['add_5[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 3, 3, 512)    1180160     ['re_lu_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 3, 3, 512)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 3, 3, 512)    2359808     ['re_lu_13[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 3, 3, 512)    131584      ['re_lu_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_19[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 3, 3, 512)    0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  re_lu_14 (ReLU)                (None, 3, 3, 512)    0           ['add_6[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 2, 2, 512)    2359808     ['re_lu_14[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 2, 2, 512)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 2, 2, 512)    2359808     ['re_lu_15[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 2, 2, 512)    262656      ['re_lu_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 2, 2, 512)    0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  re_lu_16 (ReLU)                (None, 2, 2, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_16[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1)            513         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11,539,969
# Trainable params: 11,528,577
# Non-trainable params: 11,392
# __________________________________________________________________________________________________

# %%
class ResNet18(Model):

  def __init__(self, classifier, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.classifier = classifier
    self.weight = 0.1

  def compile(self, optimizer, entropy, metric, *args, **kwargs):
    super().compile(*args, **kwargs)

    self.optimizer = optimizer
    self.loss = entropy
    self.val_acc_metric = metric

  def train_step(self, data):

    images, labels = data
    

    with tf.GradientTape() as cls_tape:
    
      images = DiffAugment(images, policy='color,translation,cutout')

      prediction = self.classifier(images, training=True)

      losses = self.loss(labels, prediction)

    gradients_of_classifier = cls_tape.gradient(losses, self.classifier.trainable_variables)
    self.optimizer.apply_gradients(zip(gradients_of_classifier, self.classifier.trainable_variables))
    
    return {'c_loss':  losses} 

  def test_step(self, data):

    real_images, real_labels = data

    prediction = self.classifier(real_images, training=False)

    val_loss = self.loss(real_labels, prediction)

    self.val_acc_metric.update_state(real_labels, prediction)

    return {'loss': val_loss, 'acc': self.val_acc_metric.result()}

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./model_checkpoints/resnet18.{epoch:03d}',
    save_weights_only=True
)

# %%
model = ResNet18(classifier)
model.compile(optimizer, entropy, metric)
hist = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=100,
    callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/100
# 203/203 [==============================] - 58s 177ms/step - c_loss: 0.5017 - val_loss: 0.3934 - val_acc: 0.7132
# Epoch 2/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.4362 - val_loss: 0.3627 - val_acc: 0.8263
# Epoch 3/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.4106 - val_loss: 0.1286 - val_acc: 0.8399
# Epoch 4/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.3857 - val_loss: 0.1921 - val_acc: 0.8300
# Epoch 5/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.3609 - val_loss: 0.4827 - val_acc: 0.8084
# Epoch 6/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.3483 - val_loss: 0.1295 - val_acc: 0.8511
# Epoch 7/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.3222 - val_loss: 0.0434 - val_acc: 0.9153
# Epoch 8/100
# 203/203 [==============================] - 23s 116ms/step - c_loss: 0.3082 - val_loss: 0.2528 - val_acc: 0.8461
# Epoch 9/100
# 203/203 [==============================] - 25s 124ms/step - c_loss: 0.2995 - val_loss: 0.2544 - val_acc: 0.8745
# Epoch 10/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.2914 - val_loss: 0.1713 - val_acc: 0.8789
# Epoch 11/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.2766 - val_loss: 0.0175 - val_acc: 0.9116
# Epoch 12/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.2625 - val_loss: 0.0566 - val_acc: 0.9079
# Epoch 13/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.2581 - val_loss: 0.0392 - val_acc: 0.9215
# Epoch 14/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.2524 - val_loss: 0.1275 - val_acc: 0.9227
# Epoch 15/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.2446 - val_loss: 0.0453 - val_acc: 0.9190
# Epoch 16/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.2298 - val_loss: 0.0838 - val_acc: 0.9234
# Epoch 17/100
# 203/203 [==============================] - 25s 122ms/step - c_loss: 0.2204 - val_loss: 0.1834 - val_acc: 0.9258
# Epoch 18/100
# 203/203 [==============================] - 23s 116ms/step - c_loss: 0.2147 - val_loss: 0.0832 - val_acc: 0.9333
# Epoch 19/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.2057 - val_loss: 0.1504 - val_acc: 0.9333
# Epoch 20/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.1962 - val_loss: 0.0680 - val_acc: 0.9258
# Epoch 21/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.1926 - val_loss: 0.0616 - val_acc: 0.9487
# Epoch 22/100
# 203/203 [==============================] - 23s 115ms/step - c_loss: 0.1920 - val_loss: 0.1672 - val_acc: 0.9363
# Epoch 23/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.1787 - val_loss: 0.0898 - val_acc: 0.9456
# Epoch 24/100
# 203/203 [==============================] - 23s 115ms/step - c_loss: 0.1755 - val_loss: 0.0753 - val_acc: 0.9462
# Epoch 25/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.1694 - val_loss: 0.0948 - val_acc: 0.9561
# Epoch 26/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.1684 - val_loss: 0.0413 - val_acc: 0.9419
# Epoch 27/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.1506 - val_loss: 0.1587 - val_acc: 0.9438
# Epoch 28/100
# 203/203 [==============================] - 23s 115ms/step - c_loss: 0.1468 - val_loss: 0.0284 - val_acc: 0.9444
# Epoch 29/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.1444 - val_loss: 0.0712 - val_acc: 0.9203
# Epoch 30/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.1469 - val_loss: 0.0306 - val_acc: 0.9394
# Epoch 31/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.1413 - val_loss: 0.0286 - val_acc: 0.9543
# Epoch 32/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.1421 - val_loss: 0.0709 - val_acc: 0.9574
# Epoch 33/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.1247 - val_loss: 0.0569 - val_acc: 0.9518
# Epoch 34/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.1266 - val_loss: 0.0063 - val_acc: 0.9617
# Epoch 35/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.1220 - val_loss: 0.0496 - val_acc: 0.9512
# Epoch 36/100
# 203/203 [==============================] - 24s 121ms/step - c_loss: 0.1190 - val_loss: 0.1276 - val_acc: 0.9623
# Epoch 37/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.1113 - val_loss: 0.1827 - val_acc: 0.8714
# Epoch 38/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.1110 - val_loss: 0.1391 - val_acc: 0.9604
# Epoch 39/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.1110 - val_loss: 0.1202 - val_acc: 0.9407
# Epoch 40/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.1067 - val_loss: 0.0950 - val_acc: 0.9666
# Epoch 41/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0990 - val_loss: 0.0701 - val_acc: 0.9648
# Epoch 42/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0962 - val_loss: 0.0586 - val_acc: 0.9642
# Epoch 43/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.1008 - val_loss: 0.0845 - val_acc: 0.9617
# Epoch 44/100
# 203/203 [==============================] - 23s 114ms/step - c_loss: 0.1023 - val_loss: 0.0622 - val_acc: 0.9685
# Epoch 45/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0922 - val_loss: 0.0344 - val_acc: 0.9444
# Epoch 46/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0930 - val_loss: 0.0153 - val_acc: 0.9629
# Epoch 47/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.0837 - val_loss: 0.0209 - val_acc: 0.9611
# Epoch 48/100
# 203/203 [==============================] - 23s 115ms/step - c_loss: 0.0815 - val_loss: 0.0156 - val_acc: 0.9159
# Epoch 49/100
# 203/203 [==============================] - 24s 121ms/step - c_loss: 0.0861 - val_loss: 0.0540 - val_acc: 0.9524
# Epoch 50/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0797 - val_loss: 0.1092 - val_acc: 0.9574
# Epoch 51/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.0785 - val_loss: 0.0308 - val_acc: 0.9672
# Epoch 52/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0810 - val_loss: 0.0279 - val_acc: 0.9592
# Epoch 53/100
# 203/203 [==============================] - 25s 123ms/step - c_loss: 0.0718 - val_loss: 0.0924 - val_acc: 0.9710
# Epoch 54/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0742 - val_loss: 0.1537 - val_acc: 0.9555
# Epoch 55/100
# 203/203 [==============================] - 25s 125ms/step - c_loss: 0.0730 - val_loss: 0.1435 - val_acc: 0.9753
# Epoch 56/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0751 - val_loss: 0.0148 - val_acc: 0.9703
# Epoch 57/100
# 203/203 [==============================] - 25s 122ms/step - c_loss: 0.0711 - val_loss: 0.0683 - val_acc: 0.9685
# Epoch 58/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0580 - val_loss: 0.2002 - val_acc: 0.9654
# Epoch 59/100
# 203/203 [==============================] - 24s 121ms/step - c_loss: 0.0739 - val_loss: 0.0672 - val_acc: 0.9611
# Epoch 60/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0670 - val_loss: 0.0035 - val_acc: 0.9734
# Epoch 61/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0718 - val_loss: 0.0257 - val_acc: 0.9765
# Epoch 62/100
# 203/203 [==============================] - 25s 125ms/step - c_loss: 0.0630 - val_loss: 0.0113 - val_acc: 0.9722
# Epoch 63/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0501 - val_loss: 0.0048 - val_acc: 0.9691
# Epoch 64/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0702 - val_loss: 0.0216 - val_acc: 0.9740
# Epoch 65/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0475 - val_loss: 0.0010 - val_acc: 0.9679
# Epoch 66/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.0637 - val_loss: 0.0443 - val_acc: 0.9697
# Epoch 67/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0587 - val_loss: 0.0772 - val_acc: 0.9672
# Epoch 68/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0483 - val_loss: 0.0055 - val_acc: 0.9747
# Epoch 69/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.0548 - val_loss: 0.0149 - val_acc: 0.9462
# Epoch 70/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0542 - val_loss: 0.0182 - val_acc: 0.9771
# Epoch 71/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0564 - val_loss: 0.0511 - val_acc: 0.9499
# Epoch 72/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0448 - val_loss: 0.1308 - val_acc: 0.9802
# Epoch 73/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0521 - val_loss: 0.0558 - val_acc: 0.9617
# Epoch 74/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0409 - val_loss: 0.0045 - val_acc: 0.9740
# Epoch 75/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0474 - val_loss: 1.8307e-04 - val_acc: 0.9778
# Epoch 76/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0555 - val_loss: 0.0057 - val_acc: 0.9765
# Epoch 77/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0467 - val_loss: 0.0167 - val_acc: 0.9728
# Epoch 78/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0466 - val_loss: 0.0475 - val_acc: 0.9703
# Epoch 79/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0438 - val_loss: 0.0179 - val_acc: 0.9481
# Epoch 80/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0493 - val_loss: 0.0309 - val_acc: 0.9740
# Epoch 81/100
# 203/203 [==============================] - 23s 116ms/step - c_loss: 0.0443 - val_loss: 0.1220 - val_acc: 0.9765
# Epoch 82/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0442 - val_loss: 0.0717 - val_acc: 0.9808
# Epoch 83/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0403 - val_loss: 0.0159 - val_acc: 0.9802
# Epoch 84/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0381 - val_loss: 6.9932e-04 - val_acc: 0.9796
# Epoch 85/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0406 - val_loss: 0.0534 - val_acc: 0.9722
# Epoch 86/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0359 - val_loss: 0.0013 - val_acc: 0.9784
# Epoch 87/100
# 203/203 [==============================] - 24s 117ms/step - c_loss: 0.0394 - val_loss: 0.0047 - val_acc: 0.9747
# Epoch 88/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.0348 - val_loss: 0.1411 - val_acc: 0.9747
# Epoch 89/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0415 - val_loss: 0.0019 - val_acc: 0.9815
# Epoch 90/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0371 - val_loss: 0.0073 - val_acc: 0.9759
# Epoch 91/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0339 - val_loss: 0.0402 - val_acc: 0.9679
# Epoch 92/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.0361 - val_loss: 0.0026 - val_acc: 0.9784
# Epoch 93/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0331 - val_loss: 0.0056 - val_acc: 0.9808
# Epoch 94/100
# 203/203 [==============================] - 24s 118ms/step - c_loss: 0.0333 - val_loss: 0.0901 - val_acc: 0.9679
# Epoch 95/100
# 203/203 [==============================] - 25s 122ms/step - c_loss: 0.0363 - val_loss: 0.1120 - val_acc: 0.9734
# Epoch 96/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.0421 - val_loss: 0.0034 - val_acc: 0.9802
# Epoch 97/100
# 203/203 [==============================] - 24s 116ms/step - c_loss: 0.0384 - val_loss: 0.0023 - val_acc: 0.9771
# Epoch 98/100
# 203/203 [==============================] - 24s 119ms/step - c_loss: 0.0350 - val_loss: 0.0116 - val_acc: 0.9821
# Epoch 99/100
# 203/203 [==============================] - 25s 121ms/step - c_loss: 0.0309 - val_loss: 0.0971 - val_acc: 0.9790
# Epoch 100/100
# 203/203 [==============================] - 24s 120ms/step - c_loss: 0.0350 - val_loss: 0.0047 - val_acc: 0.9734

# %%
plt.suptitle('Loss')
plt.plot(hist.history['c_loss'], label='c_loss')
plt.plot(hist.history['val_acc'], label='val_acc')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
model.evaluate(tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weaponandnorm/test/test',
    image_size=(256, 256), 
    batch_size=32,
    shuffle=True
).map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y)))
# Out:
# Found 456 files belonging to 2 classes.
# 15/15 [==============================] - 42s 2s/step - loss: 0.6911 - acc: 0.8700
# [0.8486841917037964, 0.05581660568714142]

# %%
model.evaluate(tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weaponandnorm/train/train',
    image_size=(256, 256), 
    batch_size=32,
    shuffle=True
).map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y)))
# Out:
# Found 1513 files belonging to 2 classes.
#  2/48 [>.............................] - ETA: 14s - loss: 2.4450 - acc: 0.5938
