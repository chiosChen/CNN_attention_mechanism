# %%
import tensorflow as tf
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Model
import os
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import Model
import tensorflow_datasets as tfds
import glob
import imageio
import PIL
from IPython import display
import time
import random

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weaponandnorm/train/train',
    image_size=(256, 256), 
    batch_size=32
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/weaponandnorm/test/test',
    image_size=(256, 256), 
    batch_size=32
)
# Out:
# Found 1513 files belonging to 2 classes.
# Found 456 files belonging to 2 classes.

# %%
class_names = ['Norm', 'Weapon']

fig = plt.figure(figsize=(9, 12))
for image, label in train_ds.take(1):
  for i in range(3):
    print()
    plt.subplot(1, 3, i + 1)
    plt.imshow((image[i]).numpy().astype('int32'))
    plt.title(class_names[label[i].numpy()])
    plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.layers.Rescaling(1./127.5, offset=-1)(x), y))

# %%
optimizer = tf.keras.optimizers.Adam()

entropy = tf.keras.losses.BinaryCrossentropy()

metric = tf.keras.metrics.BinaryAccuracy()

# %%
def DiffAugment(x, policy='', channels_first=False):
    if policy:
        if channels_first:
            x = tf.transpose(x, [0, 2, 3, 1])
        for p in policy.split(','):
            for f in AUGMENT_FNS[p]:
                x = f(x)
        if channels_first:
            x = tf.transpose(x, [0, 3, 1, 2])
    return x


def rand_brightness(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) - 0.5
    x = x + magnitude
    return x


def rand_saturation(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) * 2
    x_mean = tf.reduce_mean(x, axis=3, keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_contrast(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) + 0.5
    x_mean = tf.reduce_mean(x, axis=[1, 2, 3], keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_translation(x, ratio=0.125):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    shift = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    translation_x = tf.random.uniform([batch_size, 1], -shift[0], shift[0] + 1, dtype=tf.int32)
    translation_y = tf.random.uniform([batch_size, 1], -shift[1], shift[1] + 1, dtype=tf.int32)
    grid_x = tf.clip_by_value(tf.expand_dims(tf.range(image_size[0], dtype=tf.int32), 0) + translation_x + 1, 0, image_size[0] + 1)
    grid_y = tf.clip_by_value(tf.expand_dims(tf.range(image_size[1], dtype=tf.int32), 0) + translation_y + 1, 0, image_size[1] + 1)
    x = tf.gather_nd(tf.pad(x, [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_x, -1), batch_dims=1)
    x = tf.transpose(tf.gather_nd(tf.pad(tf.transpose(x, [0, 2, 1, 3]), [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_y, -1), batch_dims=1), [0, 2, 1, 3])
    return x


def rand_cutout(x, ratio=0.5):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    cutout_size = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    offset_x = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[0] + (1 - cutout_size[0] % 2), dtype=tf.int32)
    offset_y = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[1] + (1 - cutout_size[1] % 2), dtype=tf.int32)
    grid_batch, grid_x, grid_y = tf.meshgrid(tf.range(batch_size, dtype=tf.int32), tf.range(cutout_size[0], dtype=tf.int32), tf.range(cutout_size[1], dtype=tf.int32), indexing='ij')
    cutout_grid = tf.stack([grid_batch, grid_x + offset_x - cutout_size[0] // 2, grid_y + offset_y - cutout_size[1] // 2], axis=-1)
    mask_shape = tf.stack([batch_size, image_size[0], image_size[1]])
    cutout_grid = tf.maximum(cutout_grid, 0)
    cutout_grid = tf.minimum(cutout_grid, tf.reshape(mask_shape - 1, [1, 1, 1, 3]))
    mask = tf.maximum(1 - tf.scatter_nd(cutout_grid, tf.ones([batch_size, cutout_size[0], cutout_size[1]], dtype=tf.float32), mask_shape), 0)
    x = x * tf.expand_dims(mask, axis=3)
    return x


AUGMENT_FNS = { 
    'color': [rand_brightness, rand_saturation, rand_contrast],
    'translation': [rand_translation],
    'cutout': [rand_cutout]
}

# %%
def VGG16():
    model = tf.keras.models.Sequential()
    
    model.add(layers.Conv2D(input_shape=(256,256,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(units=4096,activation="relu"))
    model.add(layers.Dense(units=4096,activation="relu"))
    model.add(layers.Dense(units=1, activation="sigmoid"))
    
    return model

# %%
class VGG(Model):

  def __init__(self, classifier, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.classifier = classifier

  def compile(self, optimizer, entropy, metric, *args, **kwargs):
    super().compile(*args, **kwargs)

    self.optimizer = optimizer
    self.loss = entropy
    self.val_acc_metric = metric

  def train_step(self, data):

    images, labels = data
    

    with tf.GradientTape() as cls_tape:
    
      images = DiffAugment(images, policy='color,translation,cutout')

      prediction = self.classifier(images, training=True)

      losses = self.loss(labels, prediction)

    gradients_of_classifier = cls_tape.gradient(losses, self.classifier.trainable_variables)
    self.optimizer.apply_gradients(zip(gradients_of_classifier, self.classifier.trainable_variables))
    
    return {'c_loss':  losses} 

  def test_step(self, data):

    real_images, real_labels = data

    prediction = self.classifier(real_images, training=False)

    val_loss = self.loss(real_labels, prediction)

    self.val_acc_metric.update_state(real_labels, prediction)

    return {'loss': val_loss, 'acc': self.val_acc_metric.result()}

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./model_checkpoints/VGG16.{epoch:03d}',
    save_weights_only=True
)

# %%
classifier = VGG16()
model = VGG(classifier)
model.compile(optimizer, entropy, metric)
hist = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=100
)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 115s 2s/step - c_loss: 0.9162 - val_loss: 0.6839 - val_acc: 0.9627
# Epoch 2/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6931 - val_loss: 0.6740 - val_acc: 0.9627
# Epoch 3/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6925 - val_loss: 0.6667 - val_acc: 0.9627
# Epoch 4/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6924 - val_loss: 0.6628 - val_acc: 0.9627
# Epoch 5/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6924 - val_loss: 0.6606 - val_acc: 0.9627
# Epoch 6/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6594 - val_acc: 0.9627
# Epoch 7/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6923 - val_loss: 0.6584 - val_acc: 0.9627
# Epoch 8/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6923 - val_loss: 0.6579 - val_acc: 0.9627
# Epoch 9/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6578 - val_acc: 0.9627
# Epoch 10/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6923 - val_loss: 0.6576 - val_acc: 0.9627
# Epoch 11/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6574 - val_acc: 0.9627
# Epoch 12/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6574 - val_acc: 0.9627
# Epoch 13/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6574 - val_acc: 0.9627
# Epoch 14/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6923 - val_loss: 0.6573 - val_acc: 0.9627
# Epoch 15/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6923 - val_loss: 0.6573 - val_acc: 0.9627
# Epoch 16/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6573 - val_acc: 0.9627
# Epoch 17/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6923 - val_loss: 0.6573 - val_acc: 0.9627
# Epoch 18/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 19/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 20/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 21/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 22/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 23/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 24/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 25/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 26/100
# 48/48 [==============================] - 15s 323ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 27/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 28/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 29/100
# 48/48 [==============================] - 15s 323ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 30/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6923 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 31/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6923 - val_loss: 0.6573 - val_acc: 0.9627
# Epoch 32/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6923 - val_loss: 0.6576 - val_acc: 0.9627
# Epoch 33/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6922 - val_loss: 0.6572 - val_acc: 0.9627
# Epoch 34/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 35/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 36/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 37/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 38/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 39/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 40/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6571 - val_acc: 0.9627
# Epoch 41/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 42/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 43/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 44/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 45/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 46/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 47/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 48/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6570 - val_acc: 0.9627
# Epoch 49/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6569 - val_acc: 0.9627
# Epoch 50/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6922 - val_loss: 0.6569 - val_acc: 0.9627
# Epoch 51/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6569 - val_acc: 0.9627
# Epoch 52/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6568 - val_acc: 0.9627
# Epoch 58/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6568 - val_acc: 0.9627
# Epoch 59/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6922 - val_loss: 0.6568 - val_acc: 0.9627
# Epoch 60/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6567 - val_acc: 0.9627
# Epoch 61/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6567 - val_acc: 0.9627
# Epoch 62/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6567 - val_acc: 0.9627
# Epoch 63/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6567 - val_acc: 0.9627
# Epoch 64/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6567 - val_acc: 0.9627
# Epoch 65/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6566 - val_acc: 0.9627
# Epoch 66/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6922 - val_loss: 0.6566 - val_acc: 0.9627
# Epoch 67/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6566 - val_acc: 0.9627
# Epoch 68/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6566 - val_acc: 0.9627
# Epoch 69/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6566 - val_acc: 0.9627
# Epoch 70/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6565 - val_acc: 0.9627
# Epoch 71/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6565 - val_acc: 0.9627
# Epoch 72/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6565 - val_acc: 0.9627
# Epoch 73/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6565 - val_acc: 0.9627
# Epoch 74/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6565 - val_acc: 0.9627
# Epoch 75/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6564 - val_acc: 0.9627
# Epoch 76/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6922 - val_loss: 0.6564 - val_acc: 0.9627
# Epoch 77/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6564 - val_acc: 0.9627
# Epoch 78/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6564 - val_acc: 0.9627
# Epoch 79/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6563 - val_acc: 0.9627
# Epoch 80/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6563 - val_acc: 0.9627
# Epoch 81/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6563 - val_acc: 0.9627
# Epoch 82/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6563 - val_acc: 0.9627
# Epoch 83/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6922 - val_loss: 0.6562 - val_acc: 0.9627
# Epoch 84/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6562 - val_acc: 0.9627
# Epoch 85/100
# 48/48 [==============================] - 15s 319ms/step - c_loss: 0.6922 - val_loss: 0.6562 - val_acc: 0.9627
# Epoch 86/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6562 - val_acc: 0.9627
# Epoch 87/100
# 48/48 [==============================] - 15s 321ms/step - c_loss: 0.6922 - val_loss: 0.6561 - val_acc: 0.9627
# Epoch 88/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6561 - val_acc: 0.9627
# Epoch 89/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6561 - val_acc: 0.9627
# Epoch 90/100
# 48/48 [==============================] - 15s 322ms/step - c_loss: 0.6922 - val_loss: 0.6561 - val_acc: 0.9627
# Epoch 91/100
# 48/48 [==============================] - 15s 317ms/step - c_loss: 0.6922 - val_loss: 0.6560 - val_acc: 0.9627
# Epoch 92/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6560 - val_acc: 0.9627
# Epoch 93/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6560 - val_acc: 0.9627
# Epoch 94/100
# 48/48 [==============================] - 16s 324ms/step - c_loss: 0.6922 - val_loss: 0.6560 - val_acc: 0.9627
# Epoch 95/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6559 - val_acc: 0.9627
# Epoch 96/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6559 - val_acc: 0.9627
# Epoch 97/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6559 - val_acc: 0.9627
# Epoch 98/100
# 48/48 [==============================] - 15s 320ms/step - c_loss: 0.6922 - val_loss: 0.6559 - val_acc: 0.9627
# Epoch 99/100
# 48/48 [==============================] - 15s 318ms/step - c_loss: 0.6922 - val_loss: 0.6558 - val_acc: 0.9627
# Epoch 100/100
# 48/48 [==============================] - 15s 316ms/step - c_loss: 0.6922 - val_loss: 0.6558 - val_acc: 0.9627

# %%
plt.suptitle('Loss')
plt.plot(hist.history['c_loss'], label='c_loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.plot(hist.history['val_acc'], label='val_acc')
plt.legend()
plt.show()

# %%
model.evaluate(train_ds)
# Out:
# 48/48 [==============================] - 4s 82ms/step - loss: 0.6921 - acc: 0.5159
# [0.5181757807731628, 0.681185781955719]
